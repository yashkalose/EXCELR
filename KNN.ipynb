# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("Zoo.csv")

# %%
data
# Out:
#     animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  type
# 0          1     1
# 1          1     1
# 2          0     4
# 3          1     1
# 4          1     1
# ..       ...   ...
# 96         1     1
# 97         0     6
# 98         1     1
# 99         0     7
# 100        0     2
#
# [101 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal name  101 non-null    object
#  1   hair         101 non-null    int64
#  2   feathers     101 non-null    int64
#  3   eggs         101 non-null    int64
#  4   milk         101 non-null    int64
#  5   airborne     101 non-null    int64
#  6   aquatic      101 non-null    int64
#  7   predator     101 non-null    int64
#  8   toothed      101 non-null    int64
#  9   backbone     101 non-null    int64
#  10  breathes     101 non-null    int64
#  11  venomous     101 non-null    int64
#  12  fins         101 non-null    int64
#  13  legs         101 non-null    int64
#  14  tail         101 non-null    int64
#  15  domestic     101 non-null    int64
#  16  catsize      101 non-null    int64
#  17  type         101 non-null    int64
# dtypes: int64(17), object(1)
# memory usage: 14.3+ KB

# %%
data[data.duplicated()].count()
# Out:
# animal name    0
# hair           0
# feathers       0
# eggs           0
# milk           0
# airborne       0
# aquatic        0
# predator       0
# toothed        0
# backbone       0
# breathes       0
# venomous       0
# fins           0
# legs           0
# tail           0
# domestic       0
# catsize        0
# type           0
# dtype: int64

# %%
data.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor = data.corr(method='pearson')
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_54b98_row0_col0, #T_54b98_row1_col1, #T_54b98_row2_col2, #T_54b98_row3_col3, #T_54b98_row4_col4, #T_54b98_row5_col5, #T_54b98_row6_col6, #T_54b98_row7_col7, #T_54b98_row8_col8, #T_54b98_row9_col9, #T_54b98_row10_col10, #T_54b98_row11_col11, #T_54b98_row12_col12, #T_54b98_row13_col13, #T_54b98_row14_col14, #T_54b98_row15_col15, #T_54b98_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col1, #T_54b98_row0_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col2, #T_54b98_row5_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col3 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col4, #T_54b98_row1_col12 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_54b98_row0_col5, #T_54b98_row9_col10, #T_54b98_row16_col14 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col6, #T_54b98_row2_col14 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_54b98_row0_col8, #T_54b98_row8_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_54b98_row0_col9 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_54b98_row0_col11 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_54b98_row0_col12 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_54b98_row0_col13 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_54b98_row0_col14, #T_54b98_row4_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_54b98_row0_col15 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_54b98_row0_col16, #T_54b98_row7_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col0, #T_54b98_row3_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col2, #T_54b98_row9_col3, #T_54b98_row15_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_54b98_row1_col3, #T_54b98_row12_col7 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_54b98_row1_col4 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col5, #T_54b98_row10_col7, #T_54b98_row14_col16 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_54b98_row1_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col8, #T_54b98_row13_col7 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_54b98_row1_col9 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_54b98_row1_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_54b98_row1_col11, #T_54b98_row2_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_54b98_row1_col13, #T_54b98_row7_col15, #T_54b98_row9_col8, #T_54b98_row11_col2, #T_54b98_row11_col8, #T_54b98_row14_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_54b98_row1_col14, #T_54b98_row16_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_54b98_row1_col15, #T_54b98_row2_col13, #T_54b98_row12_col1, #T_54b98_row13_col6, #T_54b98_row14_col5, #T_54b98_row15_col14 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_54b98_row1_col16, #T_54b98_row5_col1, #T_54b98_row15_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_54b98_row2_col0, #T_54b98_row2_col3, #T_54b98_row2_col7, #T_54b98_row3_col2, #T_54b98_row3_col10, #T_54b98_row5_col9, #T_54b98_row6_col14, #T_54b98_row7_col1, #T_54b98_row7_col4, #T_54b98_row8_col10, #T_54b98_row8_col16, #T_54b98_row9_col5, #T_54b98_row9_col11, #T_54b98_row11_col12, #T_54b98_row14_col6, #T_54b98_row16_col8, #T_54b98_row16_col13, #T_54b98_row16_col15 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_54b98_row2_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_54b98_row2_col4, #T_54b98_row7_col11, #T_54b98_row9_col12 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_54b98_row2_col5, #T_54b98_row6_col5 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_54b98_row2_col8, #T_54b98_row5_col10, #T_54b98_row5_col15 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_54b98_row2_col9, #T_54b98_row5_col12, #T_54b98_row7_col2, #T_54b98_row15_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_54b98_row2_col10, #T_54b98_row8_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_54b98_row2_col11, #T_54b98_row6_col8 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_54b98_row2_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_54b98_row2_col15, #T_54b98_row12_col11 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_54b98_row2_col16 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col5, #T_54b98_row11_col14 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col7 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_54b98_row3_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_54b98_row3_col9, #T_54b98_row15_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_54b98_row3_col11, #T_54b98_row4_col5, #T_54b98_row4_col14, #T_54b98_row16_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_54b98_row3_col12, #T_54b98_row8_col11, #T_54b98_row13_col11, #T_54b98_row14_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_54b98_row3_col13, #T_54b98_row8_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_54b98_row3_col14, #T_54b98_row10_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_54b98_row3_col15, #T_54b98_row7_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_54b98_row3_col16 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_54b98_row4_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col2, #T_54b98_row5_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_54b98_row4_col3, #T_54b98_row11_col0, #T_54b98_row15_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_54b98_row4_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col9, #T_54b98_row14_col0 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_54b98_row4_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col11 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col12, #T_54b98_row8_col5, #T_54b98_row11_col3, #T_54b98_row14_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_54b98_row4_col13, #T_54b98_row10_col0, #T_54b98_row10_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_54b98_row4_col15, #T_54b98_row16_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_54b98_row4_col16, #T_54b98_row5_col8, #T_54b98_row14_col9 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_54b98_row5_col0, #T_54b98_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_54b98_row5_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_54b98_row5_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_54b98_row5_col6, #T_54b98_row8_col1, #T_54b98_row12_col16 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_54b98_row5_col7, #T_54b98_row14_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_54b98_row5_col11 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_54b98_row5_col13, #T_54b98_row6_col0, #T_54b98_row11_col15 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_54b98_row5_col16, #T_54b98_row10_col16 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_54b98_row6_col1, #T_54b98_row6_col12, #T_54b98_row8_col14, #T_54b98_row10_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_54b98_row6_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_54b98_row6_col3, #T_54b98_row6_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_54b98_row6_col9 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_54b98_row6_col10, #T_54b98_row7_col14, #T_54b98_row10_col1, #T_54b98_row12_col14 {
#   bac

# %%
x=data.iloc[:,1:17]
y=data.iloc[:,17]

# %%
#finding the best k value
k_range = range(1, 40)
k_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, x, y, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())

pd.Series(k_scores).sort_values(ascending=False)
# Out:
# 0     0.980000
# 2     0.950000
# 1     0.940000
# 3     0.920000
# 4     0.880909
# 5     0.870909
# 6     0.841818
# 7     0.811818
# 15    0.781818
# 21    0.781818
# 20    0.781818
# 18    0.781818
# 17    0.781818
# 16    0.781818
# 19    0.781818
# 14    0.781818
# 12    0.781818
# 11    0.781818
# 10    0.781818
# 9     0.781818
# 8     0.781818
# 13    0.781818
# 22    0.771818
# 23    0.741818
# 24    0.721818
# 28    0.702727
# 30    0.702727
# 29    0.702727
# 27    0.702727
# 26    0.702727
# 25    0.702727
# 31    0.692727
# 32    0.643636
# 33    0.593636
# 34    0.593636
# 35    0.573636
# 36    0.573636
# 37    0.573636
# 38    0.573636
# dtype: float64

# %%
plt.plot(k_range,k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %%
KFold=KFold(n_splits=10)
model=KNeighborsClassifier(n_neighbors=2)
results=cross_val_score(model,x,y,cv=KFold)
results
# Out:
# array([1. , 0.9, 1. , 1. , 1. , 0.9, 1. , 0.8, 0.9, 0.9])

# %%
print(results.mean())
# Out:
# 0.9400000000000001

# %% [markdown]
# DATA 2

# %%
data2=pd.read_csv("glass.csv")

# %%
data2
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
data2[data2.duplicated()].count()
# Out:
# RI      1
# Na      1
# Mg      1
# Al      1
# Si      1
# K       1
# Ca      1
# Ba      1
# Fe      1
# Type    1
# dtype: int64

# %%
data3=data2.drop_duplicates()

# %%
data3[data3.duplicated()].count()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
data3.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
cor = data3.corr(method='pearson')
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a9d2b_row0_col0, #T_a9d2b_row1_col1, #T_a9d2b_row2_col2, #T_a9d2b_row3_col3, #T_a9d2b_row4_col4, #T_a9d2b_row5_col5, #T_a9d2b_row6_col6, #T_a9d2b_row7_col7, #T_a9d2b_row8_col8, #T_a9d2b_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_a9d2b_row0_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col4, #T_a9d2b_row1_col8, #T_a9d2b_row2_col1, #T_a9d2b_row2_col3, #T_a9d2b_row2_col6, #T_a9d2b_row2_col7, #T_a9d2b_row2_col9, #T_a9d2b_row4_col0, #T_a9d2b_row6_col1, #T_a9d2b_row6_col5, #T_a9d2b_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_a9d2b_row0_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_a9d2b_row0_col8, #T_a9d2b_row9_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_a9d2b_row0_col9, #T_a9d2b_row4_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a9d2b_row1_col0, #T_a9d2b_row5_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_a9d2b_row1_col2, #T_a9d2b_row2_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_a9d2b_row1_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_a9d2b_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a9d2b_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_a9d2b_row1_col6, #T_a9d2b_row4_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_a9d2b_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a9d2b_row1_col9, #T_a9d2b_row9_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_a9d2b_row2_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a9d2b_row2_col5, #T_a9d2b_row9_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a9d2b_row2_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a9d2b_row3_col0, #T_a9d2b_row5_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a9d2b_row3_col1, #T_a9d2b_row7_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_a9d2b_row3_col2, #T_a9d2b_row6_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_a9d2b_row3_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_a9d2b_row3_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a9d2b_row3_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_a9d2b_row3_col7, #T_a9d2b_row7_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_a9d2b_row3_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_a9d2b_row3_col9 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_a9d2b_row4_col1, #T_a9d2b_row4_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a9d2b_row4_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_a9d2b_row4_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_a9d2b_row4_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_a9d2b_row4_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a9d2b_row5_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a9d2b_row5_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_a9d2b_row5_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_a9d2b_row5_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_a9d2b_row5_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_a9d2b_row5_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a9d2b_row5_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a9d2b_row6_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_a9d2b_row6_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_a9d2b_row6_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a9d2b_row6_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_a9d2b_row6_col8 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a9d2b_row6_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_a9d2b_row7_col1, #T_a9d2b_row8_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a9d2b_row7_col2, #T_a9d2b_row7_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_a9d2b_row7_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_a9d2b_row7_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a9d2b_row7_col6, #T_a9d2b_row8_col5, #T_a9d2b_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_a9d2b_row7_col9 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_a9d2b_row8_col0, #T_a9d2b_row9_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a9d2b_row8_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a9d2b_row8_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_a9d2b_row8_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_a9d2b_row8_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_a9d2b_row8_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a9d2b_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_a9d2b_row9_col1 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_a9d2b_row9_col3 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_a9d2b_row9_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a9d2b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9d2b_level0_col0" class="col_heading level0 col0" >RI</th>
#       <th id="T_a9d2b_level0_col1" class="col_heading level0 col1" >Na</th>
#       <th id="T_a9d2b_level0_col2" class="col_heading level0 col2" >Mg</th>
#       <th id="T_a9d2b_level0_col3" class="col_heading level0 col3" >Al</th>
#       <th id="T_a9d2b_level0_col4" class="col_heading level0 col4" >Si</th>
#       <th id="T_a9d2b_level0_col5" class="col_heading level0 col5" >K</th>
#       <th id="T_a9d2b_level0_col6" class="col_heading level0 col6" >Ca</th>
#       <th id="T_a9d2b_level0_col7" class="col_heading level0 col7" >Ba</th>
#       <th id="T_a9d2b_level0_col8" class="col_heading level0 col8" >Fe</th>
#       <th id="T_a9d2b_level0_col9" class="col_heading level0 col9" >Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9d2b_level0_row0" class="row_heading level0 row0" >RI</th>
#       <td id="T_a9d2b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a9d2b_row0_col1" class="data row0 col1" >-0.198802</td>
#       <td id="T_a9d2b_row0_col2" class="data row0 col2" >-0.127526</td>
#       <td id="T_a9d2b_row0_col3" class="data row0 col3" >-0.400973</td>
#       <td id="T_a9d2b_row0_col4" class="data row0 col4" >-0.539000</td>
#       <td id="T_a9d2b_row0_col5" class="data row0 col5" >-0.287645</td>
#       <td id="T_a9d2b_row0_col6" class="data row0 col6" >0.811183</td>
#       <td id="T_a9d2b_row0_col7" class="data row0 col7" >0.001679</td>
#       <td id="T_a9d2b_row0_col8" class="data row0 col8" >0.147083</td>
#       <td id="T_a9d2b_row0_col9" class="data row0 col9" >-0.160140</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2b_level0_row1" class="row_heading level0 row1" >Na</th>
#       <td id="T_a9d2b_row1_col0" class="data row1 col0" >-0.198802</td>
#       <td id="T_a9d2b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a9d2b_row1_col2" class="data row1 col2" >-0.278420</td>
#       <td id="T_a9d2b_row1_col3" class="data row1 col3" >0.167735</td>
#       <td id="T_a9d2b_row1_col4" class="data row1 col4" >-0.064885</td>
#       <td id="T_a9d2b_row1_col5" class="data row1 col5" >-0.264158</td>
#       <td id="T_a9d2b_row1_col6" class="data row1 col6" >-0.278194</td>
#       <td id="T_a9d2b_row1_col7" class="data row1 col7" >0.329080</td>
#       <td id="T_a9d2b_row1_col8" class="data row1 col8" >-0.239374</td>
#       <td id="T_a9d2b_row1_col9" class="data row1 col9" >0.508837</td>
#     </tr>
#     <tr>
#       <th id="T_a9d2b_level0_row2" class="row_heading level0 row2" >Mg</th>
#       <td id="T_a9d2b_row2_col0" class="data row2 col0" >-0.127526</td>
#       <td id="T_a9d2b_row2_col1" class="data row2 col1" >-0.278420</td>
#       <td id="T_a9d2b_

# %%
x=data3.iloc[:,0:9]
y=data3.iloc[:,9]

# %%
# best k value
k_range = range(1, 40)
k_scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, x, y, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())

pd.Series(k_scores).sort_values(ascending=False)
# Out:
# 0     0.638961
# 5     0.638961
# 2     0.633983
# 21    0.630087
# 25    0.629870
# 4     0.629221
# 24    0.625758
# 23    0.625541
# 19    0.625325
# 27    0.625108
# 3     0.624459
# 22    0.620779
# 26    0.620563
# 29    0.620346
# 28    0.620346
# 6     0.619913
# 15    0.616017
# 18    0.615801
# 20    0.615801
# 17    0.615584
# 16    0.611039
# 7     0.611039
# 30    0.610823
# 11    0.606710
# 9     0.606494
# 14    0.606494
# 13    0.606494
# 31    0.606277
# 32    0.606277
# 12    0.601948
# 33    0.601515
# 10    0.597186
# 1     0.596753
# 34    0.596753
# 35    0.591991
# 36    0.591775
# 8     0.587662
# 38    0.587229
# 37    0.582684
# dtype: float64

# %%
plt.plot(k_range,k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %%
KFold=KFold(n_splits=10)
model=KNeighborsClassifier(n_neighbors=5)
results=cross_val_score(model,x,y,cv=KFold)
results
# Out:
# array([0.45454545, 0.81818182, 0.5       , 0.9047619 , 0.28571429,
#        0.57142857, 0.52380952, 0.        , 0.19047619, 0.9047619 ])

# %%
print(results.mean())
# Out:
# 0.5153679653679654

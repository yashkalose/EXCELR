# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkalose/EXCELR/blob/main/hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### QUESTION 1

# %%
import scipy
import pandas as pd

# %%
data=pd.read_csv("Cutlets.csv")

# %%
data.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
df1=data.iloc[:,0]
df2=data.iloc[:,1]

# %%
scipy.stats.ttest_ind(df1,df2)
# Out:
# Ttest_indResult(statistic=0.7228688704678063, pvalue=0.4722394724599501)

# %%
# since level of significance is LESSER then the p value the diameter of the cutlets of 2 units are same

# %% [markdown]
# ### QUESTION 3

# %%
data1=pd.read_csv("BuyerRatio.csv")

# %%
data1.head()
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
import scipy.stats as stats
stats.f_oneway(data1.iloc[:,1],data1.iloc[:,2],data1.iloc[:,3],data1.iloc[:,4])
# Out:
# F_onewayResult(statistic=0.3068565327605033, pvalue=0.8204060154887464)

# %%
#SINCE PVALUE > 0.05 WE ACCEPT NULL HYPOTHESIS i.e the sales of product in all 4 regions are same for male and female

# %% [markdown]
# ### QUESTION 2

# %%
data=pd.read_csv("LabTAT.csv")

# %%
data.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
import scipy.stats as stats
stats.f_oneway(data.iloc[:,0],data.iloc[:,1],data.iloc[:,2],data.iloc[:,3])
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
#SSB df=k-1=4-1=3
#SSE df=N-k=5-4=1
#CV=215.70
#SINCE TS<CV THE AVERAGE TAT FROM 4 LABORATRIES ARE SIMILAR

# %% [markdown]
# ### QUESTION 4

# %%
import numpy as np
from scipy.stats import chi2_contingency

# %%
data=pd.read_csv("/content/Costomer+OrderForm (1).csv")

# %%
data.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
data.Phillippines.value_counts()
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64

# %%
data.Indonesia.value_counts()
# Out:
# Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64

# %%
data.Malta.value_counts()
# Out:
# Error Free    269
# Defective      31
# Name: Malta, dtype: int64

# %%
data.India.value_counts()
# Out:
# Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
obs=np.array([[271,267,269,280],[29,33,31,20]])

# %%
chi2_contingency(obs) # o/p is (Chi2 stats value, p_value, df, expected obsvations)
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
#since pvalue is greater than 0.05, customer order forms defective % does not varies by centre
